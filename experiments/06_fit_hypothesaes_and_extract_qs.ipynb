# %%
# %load_ext autoreload
# %autoreload 2

import os
import joblib
import numpy as np
import pandas as pd
from neuro import config
import neuro.agent
import neuro.decoding
from sklearn.model_selection import train_test_split
import imodelsx.llm
from tqdm import tqdm

INTERPRETER_MODEL = "gpt-4.1"
# ANNOTATOR_MODEL = 'meta-llama/Meta-Llama-3-8B-Instruct' # not actually used
EMBEDDER = "nomic-ai/modernbert-embed-base" # Huggingface model, will run locally
TASK_SPECIFIC_INSTRUCTIONS = """All of the texts are from a narrative story.
Features should describe a specific aspect of the text. For example:
- "The input mentions a location"
- "The input mentions time"
""".strip()

# paths
os.makedirs(config.HYPOTHESAES_RESULTS_DIR, exist_ok=True)
os.environ['EMB_CACHE_DIR'] = os.path.join(config.HYPOTHESAES_RESULTS_DIR, 'emb_cache')
# CACHE_NAME = f"yelp_quickstart_{EMBEDDER.replace('/', '___')}"
CACHE_NAME = f"neuro_quickstart_{EMBEDDER.replace('/', '___')}"
checkpoint_dir = os.path.join(config.HYPOTHESAES_RESULTS_DIR, "checkpoints", CACHE_NAME)


# import these after
from neuro.baselines.hypothesaes.quickstart import train_sae, interpret_sae, generate_hypotheses, evaluate_hypotheses
from neuro.baselines.hypothesaes.embedding import get_local_embeddings
neuro.baselines.hypothesaes.embedding.CACHE_DIR = os.environ['EMB_CACHE_DIR']
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# **Load data**
#
# The dataset we're using here is a subset of 20K Yelp reviews, with 2K reviews used for validation (during SAE training).
#
# The target variable is the `stars` column, which is a rating between 1 and 5. We treat this as a regression task.
#
# There are also 2K reviews used for holdout evaluation, which we'll use at the end of the notebook.

# %%
# Example usage:
df_train, texts_train = neuro.decoding.get_shared_data_for_subjects(
    ['UTS01', 'UTS02', 'UTS03'],
    train_or_test='train',
    concatenate_running_texts_frac=0.5
)
texts_train = [x.strip() for x in texts_train if isinstance(x, str)]  # Ensure all entries are strings
# remove empty indexes
idxs_empty = [i for i, text in enumerate(texts_train) if not text]
texts_train = [text for i, text in enumerate(texts_train) if i not in idxs_empty]
df_train = df_train.reset_index(drop=True).drop(index=idxs_empty)
df_train, df_val, texts_train, texts_val = train_test_split(df_train, texts_train, test_size=0.2, random_state=42)
assert len(texts_train) == len(df_train)
labels_train_multitarget = df_train.values

# %% [markdown]
# **Compute text embeddings for your dataset**
#
# We'll compute text embeddings for a training set, and optionally a validation set. The validation embeddings are used for SAE eval and early-stopping during training.
#
# Embeddings will be stored in the `emb_cache` directory (or `os.environ["EMB_CACHE_DIR"]` if you set it) using the `cache_name` parameter, so you only need to compute embeddings once.
#
# You can use OpenAI or a local model.
#
# Local models will run much faster on GPU. The default local model is `nomic-ai/modernbert-embed-base`. You can use any sentence-transformers model, but please read the model's docs; you may need to edit `get_local_embeddings`.

# %%
text2embedding = get_local_embeddings(texts_train + texts_val, model=EMBEDDER, batch_size=128, cache_name=CACHE_NAME)
# embeddings = np.stack([text2embedding[text] for text in texts_train])

train_embeddings = np.stack([text2embedding[text] for text in texts_train])
val_embeddings = np.stack([text2embedding[text] for text in texts_val])
joblib.dump((train_embeddings, val_embeddings), os.path.join(config.HYPOTHESAES_RESULTS_DIR, f"{CACHE_NAME}_embeddings.pkl"))

# %%
train_embeddings, val_embeddings = joblib.load(os.path.join(config.HYPOTHESAES_RESULTS_DIR, f"{CACHE_NAME}_embeddings.pkl"))

# %% [markdown]
# **Train SAE**
#
# We will train a Matryoshka SAE with $M=256$, $k=8$, and $\text{prefix\_lengths} = [32, 256]$.
#
# With the Matryoshka loss, the SAE will learn to reconstruct the input from (1) just the first 32 neurons, and (2) all 256 neurons.
# This will produce 32 coarse-grained features, and 224 finer-grained features.
#
# See the README for more details about selecting SAE hyperparameters.

# %%
sae = train_sae(embeddings=train_embeddings, val_embeddings=val_embeddings,
                M=512, K=16, matryoshka_prefix_lengths=[64, 128, 256, 512], 
                checkpoint_dir=checkpoint_dir, n_epochs=500,)
joblib.dump(sae, os.path.join(checkpoint_dir, "sae.pkl"))

# %%
sae = joblib.load(os.path.join(checkpoint_dir, "sae.pkl"))

# %% [markdown]
# **Generate hypotheses**
#
# Generate hypotheses which are predictive of the target variable.
#
# The `selection_method` parameter defines how we compute neuron predictiveness (see `src/select_neurons.py` for more details):
# - "separation_score": E[target | top-activating examples] - E[target | zero-activating examples]
# - "correlation": pearson(neuron activations, target variable)
# - "lasso": select N nonzero features with an L1 regularized model
#
# This cell outputs a dataframe with the following columns:
# - `neuron_idx`: The index of the neuron in the SAE (if you're using multiple SAEs, this will be a global index across all of them).
# - `source_sae`: The SAE that the neuron was selected from.
# - `target_{selection_method}`: The predictiveness of the neuron for the target variable, using the selected `selection_method`.
# - `interpretation`: The natural language interpretation of the neuron.
# - `interp_fidelity_score`: The F1 fidelity score for how well the neuron's interpretation actually corresponds to its activation pattern.

# %%
results = generate_hypotheses(
    texts=texts_train,
    labels=labels_train_multitarget,
    embeddings=train_embeddings,
    sae=sae,
    cache_name=CACHE_NAME,
    classification=False,

    # hyperparams
    selection_method = "correlation_multi_target",
    n_selected_neurons=384,
    n_candidate_interpretations=1,
    task_specific_instructions=TASK_SPECIFIC_INSTRUCTIONS,
    interpreter_model=INTERPRETER_MODEL,

    # provide some scoring of the hypotheses using this many examples
    n_scoring_examples=0,
    # n_scoring_examples=100,
    # annotator_model=ANNOTATOR_MODEL,
    # n_workers_annotation=N_WORKERS_ANNOTATION, # Please lower this parameter if you are running into OpenAI API rate limits
)
os.makedirs(os.path.join(config.HYPOTHESAES_RESULTS_DIR, 'interpretations'), exist_ok=True)
joblib.dump(results, os.path.join(config.HYPOTHESAES_RESULTS_DIR, 'interpretations', "results_questions.pkl"))

# %% [markdown]
# ### Save and postprocess results

# %%
results = joblib.load(os.path.join(config.HYPOTHESAES_RESULTS_DIR, 'interpretations', "results_questions.pkl"))
results['interpretation'].fillna('The input is short.', inplace=True)
# Out:
# /tmp/ipykernel_1646497/784794250.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   results['interpretation'].fillna('The input is short.', inplace=True)

# %%
print("\nMost predictive features:")
pd.set_option('display.max_colwidth', None)
display(results.sort_values(by=f"target_correlation_multi_target", ascending=False))
pd.reset_option('display.max_colwidth')

# %%
lm = imodelsx.llm.get_llm('gpt-4.1')
qs_processed = []
for i in tqdm(range(0, len(results['interpretation'].values.tolist()), 20)):
    print(f"Rewording questions {i} to {i + 20}")
    batch_qs = results['interpretation'].values.tolist()[i:i + 20]
    batch_qs_revised = neuro.agent.revise_invalid_questions_by_rewording(batch_qs, lm)
    
    for q in batch_qs_revised:
        assert q.startswith('Does the input') and q.endswith('?'), f"Question '{q}' is not properly formatted."
    qs_processed.extend(batch_qs_revised)
# qs = neuro.agent.revise_invalid_questions_by_rewording(results['interpretation'].values.tolist(), lm)

# %%
results['questions_processed'] = qs_processed
joblib.dump(results, os.path.join(config.HYPOTHESAES_RESULTS_DIR, 'interpretations', "results_questions.pkl"))

# %%
with pd.option_context('display.max_colwidth', None):
    display(results['questions_processed'].head(40))

# %%
questions_list = joblib.load(os.path.join(config.HYPOTHESAES_RESULTS_DIR, 'interpretations', "results_questions.pkl"))['questions_processed'].values.tolist()

# %%
questions
# Out:
# ['Does the input consist of a single pronoun word?',
#  "Does the input contain reported or direct speech, indicated by words like 'said', 'say', or 'says'?",
#  "Does the input contain one or more numbers expressed as words (e.g., 'fifty', 'seventy', 'thousand') or numerals, often in the context of quantities, measurements, or ranges?",
#  'Does the input mention a place such as a town, neighborhood, city, or geographic location?',
#  "Does the input explicitly mention an age or a specific number of years in reference to a person's life or the passage of time?",
#  'Does the input discuss abstract concepts, such as viewpoints, frameworks, understanding, arguments, or cultural ideas?',
#  'Does the input mention a specific time or time of day (e.g., hours, days of the week, or clock times)?',
#  'Does the input describe physical appearance, specifically mentioning hair color or skin tone?',
#  'Does the input describe someone screaming, yelling, or crying out in distress?',
#  'Does the input mention purchasing or owning physical items or products?',
#  'Does the input describe traveling in a vehicle, specifically mentioning driving or being in a car on a road or highway?',
#  'Does the input describe experiencing a strong or unusual internal physical or emotional sensation?',
#  "Does the input contain conversational filler words or phrases such as 'like', 'um', 'you know', or 'to be honest'?",
#  'Does the input express reluctance, refusal, or not wanting to do something?',
#  'Does the input describe a person sitting or being seated?',
#  'Does the input describe receiving or making a phone call?',
#  'Does the input mention clothing or garments?',
#  "Does the input contain the phrase 'was' or 'were' immediately following a pronoun (such as 'I', 'we', 'they', 'it', 'everyone', 'which', 'that'), indicating a form of the verb?",
#  'Does the input describe someone looking, seeing, or making eye contact?',
#  "Does the input contain a first-person singular pronoun ('I' or 'myself') referring to the narrator?",
#  'Does the input mention a specific US state or city by name?',
#  "Does the input contain the word 'so', often at the beginning or repeatedly, and frequently include filler words such as 'um' or 'uh'?",
#  'Does the input mention a room or specific area within a home (e.g., kitchen, bedroom, living room, dining room, attic, bathroom)?',
#  "Does the input reference knowledge, awareness, realization, or learning (using words like 'know', 'known', 'realize', 'learned', 'experienced', 'idea', 'wondering', 'astounded', 'awareness')?",
#  'Does the input describe a group of people present together or gathering?',
#  'Does the input describe a gradual or progressive change or transformation over time?',
#  'Does the input describe going to or being at an event or place outside the home?',
#  'Does the input discuss employment, specifically mentioning jobs, being hired, quitting, or work-related activities?',
#  "Does the input contain the word 'and' repeated multiple times, sometimes consecutively, possibly with filler words like 'um' or 'uh' in between?",
#  'Does the input describe someone walking or moving on foot?',
#  'Does the input mention natural landscapes or outdoor environments, such as mountains, ocean, beach, waterfalls, wilderness, golf courses, or lawns?',
#  'Does the input mention geographic regions or countries, specifically referencing Asia, Africa, Latin America, Canada, New Zealand, or South Africa?',
#  'Does the input describe a process or strategy for solving a problem or accomplishing a task?',
#  'Does the input describe or mention food or eating?',
#  "Does the input refer to a male person using third-person pronouns or descriptors (e.g., 'he', 'him', 'his', 'guy', 'father')?",
#  'Does the input describe actions related to sorting, handling, or disposing of waste, trash, or recyclables?',
#  'Does the input mention family members, specifically mother, father, mom, or dad?',
#  "Does the input contain a question or uncertainty about the identity or nature of an object, often using phrases like 'what is it', 'what is this', or 'what that is'?",
#  "Does the input contain a phrase indicating temporal progression, such as 'and then', 'and after', 'so after', 'about two weeks later', or similar expressions indicating the passage of time or sequence of events?",
#  'Does the input mention a hand or hands?',
#  "Does the input refer to a female character using the pronoun 'she' or 'her'?",
#  'Does the input express positive emotions or appreciation towards a person or situation?',
#  'Does the input describe a medical or mechanical repair procedure involving physical objects being opened, altered, or assembled?',
#  'Does the input describe or reference flying in an aircraft or being inside an aircraft?',
#  "Does the input refer to a person's name or discuss the concept of a 'name'?",
#  'Does the input describe interactions or relationships between friends or acquaintances?',
#  'Does the input describe or express intense negative emotions such as hatred, disgust, cruelty, or a desire for harm towards people?',
#  "Does the input contain the word 'know' or a variant ('knew', 'knowing', etc.)?",
#  "Does the input refer to or predict a future event using phrases like 'gonna', 'going to', 'what's gonna happen', or similar future-oriented language?",
#  'Does the input mention water as a drink or drinking water?',
#  "Does the input discuss life or living, using forms of the word 'life' or 'live'?",
#  'Does the input describe giving or transferring something (such as an object, privilege, or opportunity) to someone else?',
#  "Does the input contain the word 'you'?",
#  'Does the input mention writing, sending, or receiving letters?',
#  'Does the input discuss belief, disbelief, or the act of believing?',
#  "Does the input contain the word 'yes'?",
#  'Does the input describe or reference confident behavior, authenticity, or attempts to appear confident?',
#  'Does the input mention a face or facial features?',
#  'Does the input describe or refer to someone or something going down or falling downward?',
#  "Does the input refer to a 'side' or direction (e.g., left, right, other side, backside, counterclockwise)?",
#  "Does the input contain the filler word 'um'?",
#  'Does the input describe or refer to the act of thinking or having a thought?',
#  "Does the input contain the phrase 'we' or 'we were', indicating first-person plural narration or actions involving a group including the speaker?",
#  "Does the input contain repeated first-person pronouns (such as 'I I', 'we we', 'they they') appearing consecutively or in close succession?",
#  'Does the input mention newspapers or newspaper-related reporting (e.g., newspapers, paper, article, reporter, news, headlines, reported, associated press)?',
#  'Does the input mention a book?',
#  'Does the input mention law enforcement or the criminal justice system (e.g., police, prison, jail, guards, cop, arrested, interrogators, convicted)?',
#  'Does the input mention a year or refer to an annual time frame?',
#  'Does the input describe being held, pinned, or tightly restrained?',
#  'Does the input mention a car or SUV?',
#  "Does the input contain hypothetical statements describing what someone would do or what would happen, using phrases like 'would', 'could', or 'we'd'?",
#  'Does the input describe or reference someone being hit or hitting someone/something?',
#  'Does the input contain language expressing confusion, questioning, or uncertainty about ongoing events?',
#  'Does the input mention searching for information about oneself or others using Google or a search engine?',
#  'Does the input mention children or kids?',
#  'Does the input discuss dancing or being a dancer?',
#  'Does the input discuss or question what someone should do or is expected to do?',
#  "Does the input express a sense of emptiness, hopelessness, or absence, using words such as 'nothing', 'no', 'never', 'empty', or 'nowhere'?",
#  "Does the input reference quantities of two or three (e.g., 'two', 'three', 'third') in the context of enumerating items, events, or people?",
#  'Does the input discuss sexuality or sex?',
#  'Does the input describe something as extraordinary, amazing, or incredible?',
#  'Does the input refer to a period of one or more weeks?',
#  'Does the input discuss cleanliness or dirtiness, referencing cleaning, being clean, being dirty, or unpleasant smells?',
#  'Does the input mention the number twenty?',
#  'Does the input mention school?',
#  'Does the input describe or refer to an event that has happened, is happening, or could happen?',
#  'Does the input describe a medical situation involving hospitals, doctors, patients, or treatments?',
#  'Does the input mention movies, television shows, or other forms of entertainment media?',
#  'Does the input mention historical events or locations related to Russia or Europe during the 20th century?',
#  'Does the input describe participating in formal meetings, interviews, or discussions with organizational leaders or teams?',
#  'Does the input mention animals, specifically birds (such as geese) or mammals (such as dogs, cockerels, bunnies, foxes, mice, or rats)?',
#  'Does the input mention attending or obtaining a degree from a college or university?',
#  'Does the input is short?',
#  'Does the input mention family members (such as sister, brother, sibling, parent, or family) or the concept of family?',
#  "Does the input refer to a group or set of things or people using plural terms such as 'those', 'them', 'arrangements', or 'some of which'?",
#  "Does the input mention an exact number of years, age, or duration involving the number forty (e.g., 'forty years', 'forty two years', 'forty five seconds', 'forty hour', or being forty years old)?",
#  "Does the input refer to a long duration of time (e.g., 'long term', 'long run', 'long time', 'for years', 'for the longest time')?",
#  'Does the input reference Christianity or Christian religious concepts (such as church, theology, Jesus, priest, clergy, prayer, pastor, absolution, or atheist in a religious context)?',
#  "Does the input contain language expressing or inquiring about reasons, such as 'because', 'reason', or 'why'?",
#  'Does the input discuss the process or act of making art or being an artist?',
#  "Does the input contain the phrase 'okay' or a direct synonym ('alright', 'fine') used in a conversational context?",
#  'Does the input discuss telling or not telling a secret or information?',
#  "Does the input mention money, specifically referencing 'dollar(s)'?",
#  "Does the input express fear or being afraid, using words like 'scared', 'afraid', 'fearful', 'terrified', or 'nervous'?",
#  'Does the input mention a door?',
#  'Does the input describe someone going or coming back to a place or situation?',
#  'Does the input describe someone crying or expressing intense sadness through tears?',
#  "Does the input contain one or more questions using the word 'what'?",
#  'Does the input describe or reference the duration or length of time or distance spent on an activity or event?',
#  "Does the input mention a specific year in the format 'nineteen xx'?",
#  'Does the input mention marriage or being married?',
#  'Does the input mention political leaders, institutions, or events?',
#  "Does the input mention the word 'day'?",
#  'Does the input describe wearing or purchasing formal clothing or outfits (such as suits, dress pants, suspenders, heels, or costumes)?',
#  "Does the input describe actions being done to or directed at the narrator ('me'), often involving physical contact or threat?",
#  "Does the input contain the word 'never'?",
#  'Does the input reference age or aging?',
#  'Does the input describe ceremonies, celebrations, or rituals?',
#  'Does the input discuss understanding or the concept of understanding?',
#  'Does the input describe fire or something/someone being on fire?',
#  'Does the input mention Russia, Russians, or Russian locations?',
#  'Does the input discuss having or lacking options, choices, or possibilities?',
#  "Does the input contain the word 'but'?",
#  'Does the input mention fruits, specifically apples or oranges?',
#  'Does the input refer to asking or answering questions?',
#  "Does the input contain the word 'can' or a negation of it ('cannot', 'can't'), referring to ability or possibility?",
#  "Does the input refer to a specific moment or time using phrases like 'that moment', 'that time', or 'when'?",
#  'Does the input mention a head or heads?',
#  "Does the input express a need or requirement, using words like 'need', 'needed', or 'require'?",
#  'Does the input mention organizations or groups?',
#  'Does the input mention humor, joking, laughing, or being witty?',
#  'Does the input mention a guide dog for a blind person?',
#  'Does the input mention hair?',
#  'Does the input describe someone leaving or departing from a place or group?',
#  'Does the input mention helping or being helped?',
#  'Does the input contain vulgar or profane language?',
#  'Does the input mention music or musical elements?',
#  'Does the input discuss death or dying?',
#  'Does the input discuss giving or receiving an apology?',
#  "Does the input express uncertainty or possibility using words such as 'maybe', 'might', 'probably', 'likely', or 'may'?",
#  'Does the input mention a location in the United Kingdom (e.g., England, London, Glasgow, UK)?',
#  'Does the input describe someone turning or mention the act of turning?',
#  "Does the input contain repeated use of the word 'that' in close proximity (within a sentence or phrase)?",
#  'Does the input describe something that is repeated frequently or occurs regularly?',
#  'Does the input mention feet, toes, or shoes?',
#  'Does the input describe someone sitting down or telling someone/something to sit?',
#  "Does the input contain repeated use of the word 'they' referring to people?",
#  'Does the input describe or refer to speed, slowness, or the rate at which something happens?',
#  "Does the input describe or express feelings or emotions, often using words like 'feel', 'felt', or 'feeling'?",
#  "Does the input contain the word 'like' used as a discourse marker (i.e., as a filler or connective in informal speech, not as a verb or preposition)?",
#  'Does the input mention the number six or being six years old?',
#  'Does the input mention the full name of a notable person or scientist?',
#  "Does the input mention the narrator's mother?",
#  'Does the input describe something as beautiful, stunning, majestic, or otherwise visually attractive?',
#  'Does the input describe or refer to physical touch or the act of touching?',
#  "Does the input refer to human beings or people, using words like 'human', 'person', or 'people'?",
#  'Does the input mention the number two in reference to a unit of measurement, quantity, or period of time?',
#  "Does the input contain the word 'love' or its variants (e.g., 'loved', 'loving')?",
#  "Does the input contain the word 'just' or 'now'?",
#  "Does the input mention the number 'hundred' (either as 'hundred', 'hundreds', or as part of a larger number such as 'one hundred thousand')?",
#  'Does the input mention a Hispanic or Latino personal name or place name?',
#  'Does the input mention temperature or temperature-related concepts (such as hot, cold, heat, warming, degrees, fahrenheit, celsius, or temperature change)?',
#  'Does the input describe something being difficult, hard, or requiring a lot of effort or work?',
#  'Does the input describe a reaction of being surprised or shocked?',
#  'Does the input describe going to sleep, being asleep, or having difficulty sleeping?',
#  "Does the input express a desire or want, using variations of the words 'want', 'wanna', or 'wanted'?",
#  'Does the input reference alcohol consumption or alcoholic beverages?',
#  'Does the input discuss digital technology or electronic devices?',
#  'Does the input mention the character named Sarah?',
#  'Does the input mention a boyfriend?',
#  'Does the input mention darkness or the absence of light?',
#  'Does the input mention pies or similar pie-related words?',
#  "Does the input refer to the self using reflexive pronouns such as 'myself', 'herself', or 'selves'?",
#  'Does the input mention New York or New York City?',
#  "Does the input contain the word 'good' or 'bad' in reference to a quality, state, or judgment?",
#  'Does the input mention men or women?',
#  "Does the input mention the word 'four' or 'c4'?",
#  "Does the input contain first-person speech using informal, conversational language (e.g., 'i', 'i'm', 'i said', 'you', contractions, interjections like 'um', 'so', and direct address)?",
#  "Does the input mention having or possessing something, typically using 'have', 'has', or 'had'?",
#  'Does the input discuss or refer to words, vocabulary, or terminology?',
#  'Does the input refer to academic tests, exams, or qualifications?',
#  'Does the input mention something being small, tiny, or little in size?',
#  'Does the input mention Christmas or Christmas-related decorations or activities?',
#  "Does the input contain the word 'this'?",
#  'Does the input mention the sea, ocean, or sailing?',
#  "Does the input contain a form of the verb 'been'?",
#  'Does the input describe breathing, airways, or actions related to breathing (such as coughing, choking, taking a breath, or gulping for air)?',
#  'Does the input discuss the act of listening or being a listener?',
#  "Does the input mention the number three, either as a numeral or word, or references to third/three (such as 'three months', 'three years', 'three billion', 'three stars', 'third')?",
#  'Does the input discuss laws or legality?',
#  'Does the input describe experiencing pleasure, fun, or relief from engaging in or giving in to a specific behavior or activity?',
#  'Does the input describe waiting or the act of waiting?',
#  "Does the input compare something or someone as being 'better' or 'worse' than another?",
#  "Does the input mention making or receiving a phone call (using words like 'call', 'calls', 'calling', or 'called')?",
#  'Does the input discuss drugs or drug use?',
#  "Does the input mention repetition of events or actions, specifically using words like 'time', 'again', or phrases indicating something happening multiple times?",
#  'Does the input mention measurements of distance or depth?',
#  'Does the input mention concepts related to magic, such as wizards, witchcraft, hexes, or prophets?',
#  'Does the input mention languages or translation?',
#  'Does the input mention something being wrong?',
#  "Does the input mention the word 'thing' or 'things' as a noun referring to an item, event, or concept?",
#  'Does the input describe teaching, learning, or being taught something?',
#  "Does the input mention stopping or failing to stop (using the word 'stop' or 'stopped')?",
#  'Does the input mention rocks or stones?',
#  'Does the input mention a restaurant?',
#  'Does the input mention Jewish identity or Jewish people?',
#  "Does the input contain multiple occurrences of the word 'it'?",
#  'Does the input mention control or being in charge?',
#  'Does the input describe the beginning or start of something (such as an event, activity, period, or process)?',
#  "Does the input mention using Google or 'googling' to search for information about oneself or another person?",
#  'Does the input mention colors, specifically the color blue?',
#  'Does the input mention Indian heritage, identity, or Hindu religious references?',
#  "Does the input refer to something happening 'next' or mention the word 'next'?",
#  'Does the input describe or refer to forward movement or moving forward?',
#  "Does the input contain a form of the verb 'come' (come, came, coming)?",
#  'Does the input mention picking up or being picked up?',
#  "Does the input discuss 'options' or 'solutions' in the context of making choices or decisions?",
#  "Does the input contain the word 'all' used to refer to the entirety or totality of something?",
#  'Does the input mention a friend?',
#  "Does the input contain the word 'where' used as a question or to indicate uncertainty about location or position?",
#  'Does the input discuss economic aspects related to farming or agriculture?',
#  "Does the input mention the name 'fatima zohra'?",
#  'Does the input mention a window?',
#  'Does the input describe making a decision or choice?',
#  'Does the input describe or mention a bridge?',
#  'Does the input discuss depression or being depressed?',
#  'Does the input describe scientific research or laboratory experiments?',
#  'Does the input mention a letter?',
#  "Does the input contain the word 'ten' as a standalone word or as part of a number or phrase?",
#  "Does the input contain the word 'eight' (as a numeral or spelled out)?",
#  "Does the input describe losing or the loss of something (using words like 'lose', 'lost', or 'losing')?",
#  'Does the input mention climbing or heights (e.g., climbers, climbs, roof, cliff, avalanche, or being high up)?',
#  'Does the input refer to something or someone being behind or at the back?',
#  'Does the input express uncertainty or lack of knowledge or expectation about events?',
#  'Does the input mention France or French people?',
#  'Does the input mention a person named Max?',
#  'Does the input refer to what other people think, know, or perceive about the narrator?',
#  "Does the input contain the word 'up' as a standalone word or as part of a repeated phrase?",
#  'Does the input mention a town?',
#  "Does the input contain the word 'real' or the phrase 'really real'?",
#  'Does the input mention a grandparent (such as grandfather or great grandmother)?',
#  'Does the input mention caring or not caring about something or someone?',
#  'Does the input describe entering, being in, or interacting with an office or desk?',
#  'Does the input describe or refer to laughter or laughing?',
#  'Does the input mention a person named Mike?',
#  "Does the input mention the number five (either as a numeral or as the word 'five')?",
#  'Does the input mention someone being naked?',
#  'Does the input discuss prices, value, or financial/economic terms?',
#  'Does the input contain a fractional or percentage quantifier (e.g., percent, half, third, tenths) referring to a part or proportion of something?',
#  'Does the input mention focus, concentration, attention, or distraction?',
#  'Does the input mention topics related to Japan or other Asian countries, such as place names, cultural references, or people?',
#  'Does the input mention Italy or something Italian (such as Italian people, food, or places)?',
#  "Does the input mention the word 'sloth' or discuss the concept of sloth as a sin?",
#  'Does the input mention boys or a boy?',
#  'Does the input mention a girl or girls?',
#  "Does the input mention the name 'vijay' or 'vixen'?",
#  "Does the input mention 'silver paper'?",
#  'Does the input describe cutting or slitting, often in the context of harming or injuring a person or animal?',
#  'Does the input mention sandwiches or specific sandwich ingredients (such as cheese, egg, bacon, or cheeseburger)?',
#  'Does the input mention bullies or bullying?',
#  'Does the input mention a class or classes?',
#  "Does the input mention a specific section or department within a building or organization (e.g., 'self help section', 'children's section', 'building department')?",
#  'Does the input discuss similarity or familiarity between things?',
#  'Does the input mention going home or being at home?',
#  'Does the input describe or reference a battle, fight, or competition?',
#  'Does the input describe division, separation, or disconnect between people, groups, or perspectives?',
#  'Does the input mention a bank account or banking activity?',
#  'Does the input mention ice or frozen conditions?',
#  'Does the input mention the desert?',
#  'Does the input mention photography or taking pictures?',
#  'Does the input refer to an ending, final moment, or last occurrence of an event or time period?',
#  "Does the input contain the word 'way' or 'how' referring to manner or method?",
#  'Does the input mention a system?',
#  'Does the input discuss types or models of economies (e.g., circular economy, linear economy)?',
#  "Does the input contain the word 'cool'?",
#  "Does the input contain the token '{cg}'?",
#  'Does the input mention a house?',
#  'Does the input describe or mention an interview?',
#  'Does the input mention air travel, specifically flights or airplanes?',
#  'Does the input describe or refer to shaking or seismic movement?',
#  'Does the input discuss business, companies, or profits?',
#  "Does the input discuss a problem or problems, either directly mentioning the word 'problem' or 'problems', often in the context of identifying, questioning, or describing an issue?",
#  'Does the input mention a phone or cellphone?',
#  'Does the input mention blood?',
#  'Does the input mention scientific research or terminology related to rice or the enzyme rubisco?',
#  'Does the input describe seeing or perceiving someone or something?',
#  "Does the input discuss the concept of 'culture', explicitly mentioning the word 'culture'?",
#  'Does the input describe something being broken or breaking?',
#  "Does the input discuss processes or phenomena related to carbon dioxide, photosynthesis, or Earth's climate?",
#  'Does the input mention therapy?',
#  'Does the input mention astronauts or space exploration (including terms like astronaut, space race, spacecraft, Mars, Venus, Death Star, Sputnik)?',
#  "Does the input contain the phrase 'the' as a standalone word or immediately following conjunctions or filler words (such as 'and', 'uh', 'but', 'huh', 'else', etc.), often at the end or start of?",
#  'Does the input mention walking or going for a walk?',
#  'Does the input describe experiences or events related to working in a kitchen or cooking?',
#  'Does the input mention Greece, the Greek language, Greek people, Greek food, or the U.S. state of Georgia?',
#  'Does the input mention a taxi or cab?',
#  'Does the input mention happiness or being happy?',
#  "Does the input discuss energy imbalance or the greenhouse effect related to Earth's climate?",
#  'Does the input describe a significant event or turning point in the narrative?',
#  'Does the input mention cancer or surgery?',
#  'Does the input mention dogs?',
#  "Does the input describe an action or state involving a person (using verbs like 'created', 'worked', 'minded', 'involved', 'written', 'said', 'grown', 'liked', 'imagined', 'dealt')?",
#  "Does the input discuss safety or danger, explicitly mentioning words like 'safe' or 'dangerous'?",
#  "Does the input contain the word 'very'?",
#  'Does the input describe or refer to buying or purchasing something?',
#  'Does the input mention fish?',
#  'Does the input mention intelligence or describe someone as smart, stupid, or intelligent?',
#  'Does the input mention a plan or plans?',
#  'Does the input mention a gun or guns?',
#  'Does the input discuss or refer to conversations or talking?',
#  'Does the input mention a birthday?',
#  "Does the input contain the word 'still' used to indicate ongoing presence, action, or condition?",
#  'Does the input mention a church?',
#  "Does the input explicitly mention the word 'story' or 'stories'?",
#  'Does the input describe meeting or having met someone?',
#  'Does the input mention watching, turning on, or broadcasting television or TV?',
#  'Does the input express or discuss feelings of hatred or strong dislike?',
#  'Does the input mention obstacles, objections, or stigma?',
#  'Does the input mention nitrogen or nitrogen-containing compounds?',
#  'Does the input discuss or mention numbers or mathematics?',
#  'Does the input discuss labor, workers, or labor camps?',
#  'Does the input mention a ram (male sheep)?',
#  'Does the input mention a sister?',
#  "Does the input mention 'mary kay'?",
#  "Does the input mention a night, specifically using the word 'night'?",
#  'Does the input mention soldiers or the military?',
#  'Does the input mention an African country (specifically Kenya, Zimbabwe, Nigeria, or Africa in general)?',
#  'Does the input mention a person named Bob or Bobby?',
#  'Does the input mention a cheeseburger?',
#  'Does the input describe saving or being saved?',
#  'Does the input mention a camp?',
#  "Does the input discuss the concepts of the universe, existence, nothingness, or the definition of 'finite'?",
#  "Does the input mention Sousa (the name 'Sousa' appears or is referenced)?",
#  'Does the input mention pregnancy, babies, or infants?',
#  "Does the input mention the word 'life' or 'lives'?",
#  "Does the input mention the speaker's brother?",
#  'Does the input mention the delivery of parcels, mail, or milk by a postman, milkman, or similar delivery person?',
#  'Does the input mention the summer season?',
#  'Does the input discuss a sports team or sporting event?',
#  'Does the input mention a grocery store or stores?',
#  "Does the input contain the word 'after' referring to a sequence or event in time?",
#  'Does the input describe or mention silence or quietness?',
#  'Does the input mention a police officer?',
#  "Does the input mention the character 'jenny'?",
#  'Does the input discuss the concept of sin?',
#  "Does the input contain the word 'for' used as a preposition or conjunction?",
#  'Does the input mention a wheelchair or a chair used for mobility?',
#  'Does the input mention a location in California, specifically cities or regions such as Oakland, Los Angeles, or the Bay Area?',
#  'Does the input mention a party or social gathering?',
#  'Does the input describe something as weird, strange, or odd?',
#  'Does the input discuss agricultural crops, specifically mentioning types of grains or farming practices?',
#  "Does the input describe physical or emotional closeness, using words like 'close', 'closer', 'coming nearer', or similar terms indicating proximity?",
#  "Does the input mention the concept or word 'freedom' or 'free' in the context of personal or societal liberty?",
#  'Does the input describe running or actions involving running?',
#  'Does the input mention being on stage or performing on stage?',
#  'Does the input describe pretending, faking, or acting as someone or something that the narrator is not?',
#  'Does the input describe a significant or memorable moment?',
#  'Does the input mention Petra or Petr Velikiy (Peter the Great)?',
#  'Does the input mention dust or dusty environments?',
#  'Does the input mention an aunt or aunts?',
#  'Does the input contain references to remembering or recalling memories?',
#  "Does the input mention 'alternate Ithaca Tom'?",
#  'Does the input mention a person named David or Dad?',
#  'Does the input mention folding or folded objects, specifically referencing cranes or the act of folding (as in origami or metaphorical folding)?',
#  'Does the input mention Pajitnov or his collaborators?',
#  'Does the input describe being on or waiting for a bus or train?',
#  "Does the input mention the word 'white' referring to a person or describing someone's appearance, clothing, or group?",
#  "Does the input contain the word 'one'?",
#  'Does the input mention epilepsy or diagnostic criteria for epilepsy?',
#  "Does the input discuss the act of telling or expressing something, specifically using the word 'tell'?",
#  'Does the input describe or refer to a personal experience or the act of experiencing something?',
#  'Does the input reference events, objects, or practices related to organized group activities, such as churches, campaigns, fundraisers, memorials, or anthems?',
#  "Does the input contain the word 'down' used as a verb or part of a phrasal verb describing an action or state?",
#  'Does the input mention a sign or signs?',
#  'Does the input describe personality traits or types?',
#  'Does the input mention a person named Elene, Ethel, or Ego?',
#  'Does the input discuss adoption or being adopted?',
#  "Does the input mention global or worldwide concepts (e.g., 'world', 'global', 'international', or 'states around the world')?",
#  'Does the input mention courage or being courageous?',
#  'Does the input mention a couch?',
#  "Does the input contain the word 'before' used in a temporal context?",
#  "Does the input mention 'c4', either as a term or as part of a scientific or technical context?",
#  "Does the input contain the word 'nothing'?",
#  'Does the input mention a grandfather?']
